# %% [markdown]
# create a dictionary firstname,lastname, location, check the type

# %%
my_dict ={
    "first_name": ["Sarah", "Tolu","Esther" ],
    "last_name": ["John","James","Adam"],
    "location": ["Lagos","Benin","Sokoto"]
}
print(my_dict)
# Out:
# {'first_name': 'Sarah', 'last_name': 'John', 'location': 'Lagos'}

# %%
type(my_dict)
# Out:
# dict

# %%
my_dict2 ={
    "phone_number":["0813335672","09034567892","07012345689"],
    "Email":["sarahjohn@gamil.com","tolujamesn@gamil.com","estheradam@gamil.com"]
}
print(my_dict2)
# Out:
# {'phone_number': ['0813335672', '09034567892', '07012345689'], 'Email': ['sarahjohn@gamil.com', 'tolujamesn@gamil.com', 'estheradam@gamil.com']}
