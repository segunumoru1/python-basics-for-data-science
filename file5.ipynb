# %%
#create a list of players
list_players = ["ronaldo", "messi","boniface","osihmen","tevez","ozil","kaka","lookman"]
print(list_players)
# Out:
# ['ronaldo', 'messi', 'boniface', 'osihmen', 'tevez', 'ozil', 'kaka', 'lookman']

# %%
list_players[2] = "suarez"
print(list_players)
# Out:
# ['ronaldo', 'messi', 'suarez', 'osihmen', 'tevez', 'ozil', 'kaka', 'lookman']
