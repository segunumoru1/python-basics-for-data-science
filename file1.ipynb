# %%
Country_Capital = { "Italy":"Rome", "Nigeria":"Abuja", "Saudi Arabia":"Riyadh", "Germany":"Berlin", "Canada":"Ottawa", "Qatar":"Doha"}
print(Country_Capital)
# Out:
# {'Italy': 'Rome', 'Nigeria': 'Abuja', 'Saudi Arabia': 'Riyadh', 'Germany': 'Berlin', 'Canada': 'Ottawa', 'Qatar': 'Doha'}

# %%
type(Country_Capital)
# Out:
# dict

# %%
Country_Capital.keys()
# Out:
# dict_keys(['Italy', 'Nigeria', 'Saudi Arabia', 'Germany', 'Canada', 'Qatar'])
